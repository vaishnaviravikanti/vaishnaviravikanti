# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnaviravikanti/vaishnaviravikanti/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# DataFrame

# %%
students=['Alice','Bob','Emily','Charlie']

# %%
Scores=[90,80,65,50]

# %%
exam_results=pd.DataFrame(
    {
        "Name":students,
        "Scores":Scores
    }
)

# %%
exam_results
# Out:
#       Name  Scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %%
exam_results.loc[0,'Scores']
# Out:
# 90

# %%
exam_results.loc[:,'Scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: Scores, dtype: int64

# %%
exam_results.loc[2,:]
# Out:
# Name      Emily
# Scores       65
# Name: 2, dtype: object

# %%
exam_results["Scores"]
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: Scores, dtype: int64

# %%
exam_results.columns
# Out:
# Index(['Name', 'Scores', 'gender', 'genders'], dtype='object')

# %%
exam_results.drop('Name',axis=1 )
# Out:
#    Scores  gender genders
# 0      90    male    male
# 1      80  female  female
# 2      65    male    male
# 3      50  female  female

# %%
exam_results.drop('Name',axis=1)
# Out:
#    Scores  gender genders
# 0      90    male    male
# 1      80  female  female
# 2      65    male    male
# 3      50  female  female

# %%
exam_results.describe()
# Out:
#        Scores
# count    4.00
# mean    71.25
# std     17.50
# min     50.00
# 25%     61.25
# 50%     72.50
# 75%     82.50
# max     90.00

# %%
exam_results.rename({'Name': 'FirstName'}, axis=1)
# Out:
#   FirstName  Scores  gender genders
# 0     Alice      90    male    male
# 1       Bob      80  female  female
# 2     Emily      65    male    male
# 3   Charlie      50  female  female

# %%
exam_results.drop('genders',axis=1)
# Out:
#       Name  Scores  gender
# 0    Alice      90    male
# 1      Bob      80  female
# 2    Emily      65    male
# 3  Charlie      50  female

# %%
sparse = pd.DataFrame(
    {
    'a': [1,2,3],
    'b': [np.nan,4,np.nan],
    'c': [5, np.nan,np.nan]}

)

# %%
sparse
sparse.isna()
sparse.fillna(0)
sparse.dropna(axis=1)
exam_results.groupby('gender').mean()
# Out:
#         Scores
# gender
# female    65.0
# male      77.5

# %%
mylist=[1,2,1,2]

exam_results.groupby(mylist).get_group(1)
# Out:
#     Name  Scores gender genders
# 0  Alice      90   male    male
# 2  Emily      65   male    male

# %%
exam_results.groupby(mylist).get_group(2)
# Out:
#       Name  Scores  gender genders
# 1      Bob      80  female  female
# 3  Charlie      50  female  female

# %%
exam_results.groupby(mylist).get_group(2)
# Out:
#       Name  Scores  gender genders
# 1      Bob      80  female  female
# 3  Charlie      50  female  female

# %%
above_70 =exam_results['Scores'] > 70
above_70
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: Scores, dtype: bool

# %%
exam_results.groupby(above_70).mean()
# Out:
#         Scores
# Scores
# False     57.5
# True      85.0

# %%
contacts = pd.DataFrame(
    {
     'Name' :['Alice','Charlie'] ,
     'Tel'  :['+91 999 999 99 99', '+91 888 888 88 88'] 
    }
)

# %%
exam_results.merge(contacts, left_on='Name', right_on='Name')
# Out:
#       Name  Scores  gender genders                Tel
# 0    Alice      90    male    male  +91 999 999 99 99
# 1  Charlie      50  female  female  +91 888 888 88 88

# %%
exam_results.merge(contacts, left_on='Name', right_on ='Name', how ='outer')
# Out:
#       Name  Scores  gender genders                Tel
# 0    Alice      90    male    male  +91 999 999 99 99
# 1      Bob      80  female  female                NaN
# 2    Emily      65    male    male                NaN
# 3  Charlie      50  female  female  +91 888 888 88 88
